# %%
# !pip install sumy

# %%
import nltk
nltk.download('punkt')

# %%
from sumy.parsers.html import HtmlParser
from sumy.nlp.tokenizers import Tokenizer
from sumy.summarizers.text_rank import TextRankSummarizer
from sumy.summarizers.lex_rank import LexRankSummarizer
from sumy.summarizers.luhn import LuhnSummarizer
from sumy.summarizers.lsa import LsaSummarizer

# %%
num_sentences_in_summary = 10
url = "https://en.wikipedia.org/wiki/Control_(video_game)"
parser = HtmlParser.from_url(url, Tokenizer("english"))

# %%
model = Summarizer()

summarizer_list=("TextRankSummarizer:","LexRankSummarizer:","LuhnSummarizer:","LsaSummarizer") #list of summarizers
summarizers = [TextRankSummarizer(), LexRankSummarizer(), LuhnSummarizer(), LsaSummarizer()]

for i,summarizer in enumerate(summarizers):
    print(summarizer_list[i])
    for sentence in summarizer(parser.document, num_sentences_in_summary):
        print((sentence))
    print("-"*30)
# Out:
# TextRankSummarizer:
# Jesse uses an Object of Power known as the Hotline to listen to the lingering presence of Trench, who relays that his former management team knows the secrets of the Bureau, and Jesse hopes they may be able to tell her the whereabouts of her brother, Dylan, who was kidnapped by the FBC years prior.
# The Board grants Jesse a new ability and instructs her to find the Nail's four nodes to repair it; in the process, Jesse searches for the whereabouts of Marshall, who entered the Foundation during the initial Hiss invasion seeking to secure it.
# This enabled them to consider multiple stories they could tell, not just about the player-character but other individuals in the FBC, but this also created the challenge of how to present the stories of the other characters in the open-world format.
# The copious presence in the Oldest House of 1960s and 1970s technology such as pneumatic tubes , slide projectors and monochrome monitors , and the absence of modern-day technologies such as cell phones , is explained in-game as the result of the tendency of newer technologies to fail or malfunction within the boundaries of the Oldest House.
# [16] The relatively flat colors of the background walls made it an ideal canvas to showcase other design and lighting effects in the game, It also served well into the telekinesis powers of the game, as the concrete walls would be used in lieu of a target object when the player throws debris at foes via telekinesis, and the initially pristine spaces end up showing the results of a large, destructive battle.
# In the months leading up to the launch of the game, it was featured in a significant campaign as one of the first games to use Nvidia 's ray tracing features from the company's RTX graphics cards.
# [33] Remedy will release Control: Ultimate Edition , containing the base game, both paid DLC and additional updates, first on Steam for Windows on August 27, 2020 (tying in with the release of the "AWE" DLC), followed by release on the Epic Games Store and PlayStation 4 and Xbox One on September 10, 2020.
# This version will also be available for the PlayStation 5 and Xbox Series X after the release of those consoles, and those that own the Ultimate Edition on PlayStation 4 or Xbox One will be able to update their version to the newer console for free; however, this was not an option for those that had bought the original game.
# YearAwardCategoryResultRef
# 2018 Golden Joystick Awards Most Wanted Game
# Nominated [67] 2019 Game Critics Awards Best Original Game
# Nominated [68] Best PC Game
# Nominated
# Best Action/Adventure Game
# Nominated
# Golden Joystick Awards
# Best Storytelling
# Nominated [69][70][71] Best Visual Design
# Nominated
# Best Audio
# Nominated
# Critics' Choice Award
# Won Ultimate Game of the Year Nominated Titanium Awards Game of the Year
# Nominated [72] Best Art
# Nominated
# Best Game Design
# Nominated
# Best Narrative Design
# Nominated
# Best Adventure Game
# Nominated
# Best Soundtrack (Petri Alanko)Nominated The Game Awards 2019Game of the Year Nominated [73][74] Best Game Direction
# Nominated
# Best Narrative
# Nominated
# Best Art Direction
# Won
# Best Audio Design
# Nominated
# Best Performance (Courtney Hope)Nominated
# Best Performance (Matthew Porretta)Nominated
# Best Action/Adventure Game
# Nominated
# 2020
# New York Game Awards
# Great White Way Award for Best Acting in a Game (Courtney Hope)Won [75] Visual Effects Society Awards Outstanding Visual Effects in a Real-Time Project
# Won [76][77] 23rd Annual D.I.C.E.
# Awards Game of the Year
# Nominated [78][79] Outstanding Achievement in Art Direction
# Won
# Outstanding Achievement in Character (Jesse Faden)Nominated
# Outstanding Achievement in Game Direction
# Won
# Outstanding Achievement in Original Music Composition
# Won
# Outstanding Achievement in Story
# Nominated
# Outstanding Technical Achievement
# Nominated
# Action Game of the Year
# Won
# NAVGTR Awards
# Game of the Year
# Nominated [80][81] Animation, Technical
# Won
# Art Direction, Contemporary
# Won
# Control Design, 3D
# Won
# Direction in a Game Cinema
# Won
# Game, Original Action
# Nominated
# Graphics, Technical
# Won
# Lighting/Texturing
# Won 20th Game Developers Choice AwardsGame of the Year Nominated [82][83] Best Audio
# Won
# Best Narrative
# Nominated
# Best Technology
# Won Best Visual Art Won SXSW Gaming Awards Video Game of the Year
# Nominated [84][85] Most Promising New Intellectual Property
# Nominated
# Excellence in Art
# Nominated
# Excellence in Design
# Won
# Excellence in Narrative
# Nominated
# Excellence in Technical Achievement
# Nominated
# Excellence in Visual Achievement
# Nominated 16th British Academy Games AwardsBest Game Nominated [86][87] Game Design Nominated
# Animation
# Nominated
# Artistic Achievement
# Nominated
# Audio Achievement
# Nominated
# Music
# Nominated
# Narrative
# Nominated
# Original Property
# Nominated Performer in a Leading Role (Courtney Hope)Nominated Performer in a Supporting Role (Martti Suosalo)Won Technical Achievement Nominated
# 18th Annual G.A.N.G.
# ------------------------------
# LexRankSummarizer:
# The game was nominated for numerous video game awards, winning several related to the game's art and design.
# Picking it up, Jesse learns that it is an Object of Power known as the Service Weapon, and is transported to the Astral Plane, where she completes a ritual and is selected as the new Director by the Board.
# Jesse uses an Object of Power known as the Hotline to listen to the lingering presence of Trench, who relays that his former management team knows the secrets of the Bureau, and Jesse hopes they may be able to tell her the whereabouts of her brother, Dylan, who was kidnapped by the FBC years prior.
# The Foundation takes place in an eponymous location at the bottom of the Oldest House, where Jesse is summoned by the Board to deal with a threat to the Bureau.
# In the months leading up to the launch of the game, it was featured in a significant campaign as one of the first games to use Nvidia 's ray tracing features from the company's RTX graphics cards.
# [33] Remedy will release Control: Ultimate Edition , containing the base game, both paid DLC and additional updates, first on Steam for Windows on August 27, 2020 (tying in with the release of the "AWE" DLC), followed by release on the Epic Games Store and PlayStation 4 and Xbox One on September 10, 2020.
# ReceptionAggregate scoreAggregatorScore Metacritic (PC) 85/100 [40] (PS4) 82/100 [41] (XONE) 84/100 [42] Review scoresPublicationScore Destructoid 9/10 [43] EGM [44] Game Informer 8.75/10 [45] GameRevolution 4.5/5 [46] GameSpot 8/10 [47] GamesRadar+ [48] IGN 8.8/10 [49] PC Gamer (US) 88/100 [50] VideoGamer.com 8/10 [51] This section needs expansion .
# IGN chose Control as their " Game of the Year ", along with other awards including "Best Action-Adventure Game", "Best Video Game Art Direction", and "Best Video Game Story".
# [52] Game Informer , [53] Electronic Gaming Monthly , [54] and GamesRadar+ [55] awarded Control as their "Game of the Year", while Polygon , [56] Easy Allies , [57] USGamer [58] Giant Bomb , [59] Hardcore Gamer , [60] GameRevolution , [61] and GameSpot [62] list Control among their top 10 games of 2019.
# "Game of the Year Awards 2019" .
# ------------------------------
# LuhnSummarizer:
# As Jesse Faden (voiced by Courtney Hope), the Bureau's new Director, the player explores the Oldest House – the FBC's paranormal headquarters – and utilize powerful abilities in order to defeat a deadly enemy known as the Hiss, which has invaded and corrupted reality.
# Jesse uses an Object of Power known as the Hotline to listen to the lingering presence of Trench, who relays that his former management team knows the secrets of the Bureau, and Jesse hopes they may be able to tell her the whereabouts of her brother, Dylan, who was kidnapped by the FBC years prior.
# Jesse learns that Trench fell under the Hiss's influence during one of Darling's expeditions; he stole and concealed a second slide and used it to let the Hiss into the Oldest House to destroy what he perceived to be the threat of Hedron's takeover.
# The Board grants Jesse a new ability and instructs her to find the Nail's four nodes to repair it; in the process, Jesse searches for the whereabouts of Marshall, who entered the Foundation during the initial Hiss invasion seeking to secure it.
# [16] The relatively flat colors of the background walls made it an ideal canvas to showcase other design and lighting effects in the game, It also served well into the telekinesis powers of the game, as the concrete walls would be used in lieu of a target object when the player throws debris at foes via telekinesis, and the initially pristine spaces end up showing the results of a large, destructive battle.
# [33] Remedy will release Control: Ultimate Edition , containing the base game, both paid DLC and additional updates, first on Steam for Windows on August 27, 2020 (tying in with the release of the "AWE" DLC), followed by release on the Epic Games Store and PlayStation 4 and Xbox One on September 10, 2020.
# This version will also be available for the PlayStation 5 and Xbox Series X after the release of those consoles, and those that own the Ultimate Edition on PlayStation 4 or Xbox One will be able to update their version to the newer console for free; however, this was not an option for those that had bought the original game.
# [36] A free update, to release alongside the "AWE" DLC but available for all players, will increase the number of control points, or "hard" checkpoints in the game where saving the game is possible, including adding ones before boss fights, as well as several "soft" checkpoints where players can restart without having to travel back to a control point should Jesse die.
# YearAwardCategoryResultRef
# 2018 Golden Joystick Awards Most Wanted Game
# Nominated [67] 2019 Game Critics Awards Best Original Game
# Nominated [68] Best PC Game
# Nominated
# Best Action/Adventure Game
# Nominated
# Golden Joystick Awards
# Best Storytelling
# Nominated [69][70][71] Best Visual Design
# Nominated
# Best Audio
# Nominated
# Critics' Choice Award
# Won Ultimate Game of the Year Nominated Titanium Awards Game of the Year
# Nominated [72] Best Art
# Nominated
# Best Game Design
# Nominated
# Best Narrative Design
# Nominated
# Best Adventure Game
# Nominated
# Best Soundtrack (Petri Alanko)Nominated The Game Awards 2019Game of the Year Nominated [73][74] Best Game Direction
# Nominated
# Best Narrative
# Nominated
# Best Art Direction
# Won
# Best Audio Design
# Nominated
# Best Performance (Courtney Hope)Nominated
# Best Performance (Matthew Porretta)Nominated
# Best Action/Adventure Game
# Nominated
# 2020
# New York Game Awards
# Great White Way Award for Best Acting in a Game (Courtney Hope)Won [75] Visual Effects Society Awards Outstanding Visual Effects in a Real-Time Project
# Won [76][77] 23rd Annual D.I.C.E.
# Awards Game of the Year
# Nominated [78][79] Outstanding Achievement in Art Direction
# Won
# Outstanding Achievement in Character (Jesse Faden)Nominated
# Outstanding Achievement in Game Direction
# Won
# Outstanding Achievement in Original Music Composition
# Won
# Outstanding Achievement in Story
# Nominated
# Outstanding Technical Achievement
# Nominated
# Action Game of the Year
# Won
# NAVGTR Awards
# Game of the Year
# Nominated [80][81] Animation, Technical
# Won
# Art Direction, Contemporary
# Won
# Control Design, 3D
# Won
# Direction in a Game Cinema
# Won
# Game, Original Action
# Nominated
# Graphics, Technical
# Won
# Lighting/Texturing
# Won 20th Game Developers Choice AwardsGame of the Year Nominated [82][83] Best Audio
# Won
# Best Narrative
# Nominated
# Best Technology
# Won Best Visual Art Won SXSW Gaming Awards Video Game of the Year
# Nominated [84][85] Most Promising New Intellectual Property
# Nominated
# Excellence in Art
# Nominated
# Excellence in Design
# Won
# Excellence in Narrative
# Nominated
# Excellence in Technical Achievement
# Nominated
# Excellence in Visual Achievement
# Nominated 16th British Academy Games AwardsBest Game Nominated [86][87] Game Design Nominated
# Animation
# Nominated
# Artistic Achievement
# Nominated
# Audio Achievement
# Nominated
# Music
# Nominated
# Narrative
# Nominated
# Original Property
# Nominated Performer in a Leading Role (Courtney Hope)Nominated Performer in a Supporting Role (Martti Suosalo)Won Technical Achievement Nominated
# 18th Annual G.A.N.G.
# ------------------------------
# LsaSummarizer
# Certain areas known as Control Points can be used to fast travel throughout the building after they have been cleared of enemies.
# AWEs produce Objects of Power, which are unique in that they grant certain individuals (referred to as "parautilitarians") paranatural abilities.
# Jesse encounters various allies in the FBC, including research specialist Emily Pope ( Antonia Bernath ), security chief Simon Arish (Ronan Summers), Head of Operations Helen Marshall (Brig Bennett), and Ahti ( Martti Suosalo ), a mysterious Finnish janitor.
# Ahti gives Jesse a cassette player which enables her to navigate an elaborate maze protecting the slide projector's chamber.
# A further challenge involved creating an environment that would encourage the player to explore, get lost in it, and learn by observation.
# MacDonald said he was drawn to use a floppy disk in this manner after reading a story about how many of the United States national missile defense sites had only recently transitioned off floppy disks, and prior to that, these disks could be seen as proverbial weapons that were held with high reverence.
# The game's main voice cast was announced at New York Comic Con in 2018, consisting of various actors from Remedy's previous games.
# Among one of the these pieces includes a Finnish tango which Lake wrote, Petri Alanko composed, and Suosalo sang.
# [31] Nvidia created or hosted nine videos, including an exclusive gameplay trailer, to display the game's ray tracing integration.
# [12] The first, "Expeditions", was released as a free update on 12 December 2019, and presents standalone missions of various difficulty with power-up items for their character.
# ------------------------------
